# %%
import os
import csv
import json

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

import seaborn as sns
sns.set()

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

sns.set(font='Tahoma')  # Tahoma is easy to read at small sizes

def save_fig(filename):
    new_filename = filename.replace(' ', '-').lower()
    plt.savefig(new_filename, bbox_inches = 'tight')

# %%
# %%capture
# 'capture' silences output.
# The below cd is necessary to import local functions in parent directory
# %cd ..

from read_data import read_all_datasets

# %%
dmoz, phishing, ilp = read_all_datasets()

# %%
ax = dmoz['label'].value_counts().plot(kind='bar', figsize=(5, 1.7))
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.e'))
save_fig('dmoz.pdf')
plt.show()

# %%
ilp['label'].value_counts().plot(kind='bar', figsize=(5, 1.7))
save_fig('ilp.pdf')
plt.show()
